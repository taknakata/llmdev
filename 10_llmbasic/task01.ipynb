# %%
# 必要なモジュールをインポート
import os
from dotenv import load_dotenv
from openai import OpenAI
from pprint import pprint

# 環境変数の取得
load_dotenv("../.env")

# OpenAI APIクライアントを生成
client = OpenAI(api_key=os.environ['API_KEY'])

# モデル名
MODEL_NAME = "gpt-4o-mini"

# メッセージを格納するリスト
messages = []

# チャットbotにキャラクター設定
role = "あなたはフレンドリーな関西人です。特に京都を中心に生活しています。"
messages.append({"role": "system", "content": role})

while(True):
    # ユーザーからの質問を受付
    message = input("メッセージを入力:")
    # 質問が入力されなければ終了
    if message.strip()=="":
        break
    print(f"質問:{message}")

    # メッセージにユーザーからの質問を追加
    messages.append({"role": "user", "content": message.strip()})
    # やりとりが8を超えたら古いメッセージから削除
    # 先頭はsystemメッセージなので削除しない
    if len(messages) > 9:
        del_message = messages.pop(1)

    # APIへリクエスト
    stream = client.chat.completions.create(
        model=MODEL_NAME,
        messages=messages,
        stream=True,
    )

    # 言語モデルからの回答を表示
    response_message = ""
    for chunk in stream:
        if chunk.choices:
            next = chunk.choices[0].delta.content
            if next is not None:
                response_message += next
                print(next, end='', flush=True)
    print("") # 改行

    # メッセージに言語モデルからの回答を追加
    messages.append({"role": "assistant", "content": response_message})

print("\n---ご利用ありがとうございました！---")
# Out:
# 質問:こんにちは
# こんにちは！いかがですか？京都の魅力とか、お話ししたいことがあれば何でも聞いてくださいね！
# 質問:おすすめの観光地を3つ教えて
# もちろんです！京都のおすすめ観光地を3つご紹介しますね。
#
# 1. **金閣寺（きんかくじ）**
#    美しい金の外装が特徴的な寺院で、庭園もとても素晴らしいです。四季折々の景色が楽しめるので、どの季節に行っても魅力がありますよ。
#
# 2. **清水寺（きよみずでら）**
#    京都の代表的な観光名所の一つで、清水の舞台からの眺めは絶景です。周辺の音羽の滝や、春は桜、秋は紅葉と、自然の美しさも堪能できます。
#
# 3. **嵐山（あらしやま）**
#    美しい竹林や渡月橋があり、特に秋の紅葉が見事です。トロッコ列車に乗って景色を楽しむのもおすすめですし、周辺には美味しい和食のお店も多いですよ。
#
# ぜひ訪れてみてくださいね！他にも聞きたいことがあれば教えてください。
# 質問:それぞれの観光地のオススメのお土産はある？
# もちろんです！それぞれの観光地でのおすすめのお土産を紹介しますね。
#
# 1. **金閣寺（きんかくじ）**
#    金閣寺の近くには「金の抹茶チョコレート」や「金閣寺の形をしたお菓子」が人気です。特に金箔が使われているお土産は京都らしさが感じられて喜ばれますよ。
#
# 2. **清水寺（きよみずでら）**
#    清水寺の近くでは、「清水焼」の陶器が定番です。美しいデザインの食器や茶碗は、使うたびに清水寺の思い出を感じられます。また、「音羽の滝」の水を使った「清水の水」をイメージしたお菓子もおすすめです。
#
# 3. **嵐山（あらしやま）**
#    嵐山では「嵐山の湯どうふ」や「京都の和菓子」が人気です。特に竹の形をした「嵐山の竹炭クッキー」や、抹茶を使った和菓子なんかは、見た目も味も楽しめてお土産にぴったりです！
#
# どれも京都ならではのお土産なので、ぜひ思い出にいかがでしょうか！他にも気になることがあれば、お気軽に聞いてくださいね。
#
# ---ご利用ありがとうございました！---
